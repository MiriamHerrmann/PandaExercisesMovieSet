# %%
import numpy as np
import pandas as pd 
df=pd.read_csv("movies_2.csv")
df.head(5)
# Out:
#    MovieID                       Title MPAA Rating      Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0
#
#                                              Summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# ...

# %%
df
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %%
df_copy = df.copy()
df_copy.head()
# Find and replace command = Ctrl+H
# Out:
#    MovieID                       Title MPAA Rating      Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0
#
#                                              Summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MovieID       616 non-null    int64
#  1   Title         615 non-null    object
#  2   MPAA Rating   615 non-null    object
#  3   Budget        615 non-null    float64
#  4   Gross         615 non-null    float64
#  5   Release Date  615 non-null    object
#  6   Genre         615 non-null    object
#  7   Runtime       615 non-null    float64
#  8   Rating        508 non-null    float64
#  9   Rating Count  508 non-null    float64
#  10  Summary       496 non-null    object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 53.1+ KB

# %%
print(df_copy.shape)
#rows, columns
# Out:
# (616, 11)

# %%
#prints information on all columns
df_copy.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MovieID       616 non-null    int64
#  1   Title         615 non-null    object
#  2   MPAA Rating   615 non-null    object
#  3   Budget        615 non-null    float64
#  4   Gross         615 non-null    float64
#  5   Release Date  615 non-null    object
#  6   Genre         615 non-null    object
#  7   Runtime       615 non-null    float64
#  8   Rating        508 non-null    float64
#  9   Rating Count  508 non-null    float64
#  10  Summary       496 non-null    object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 53.1+ KB

# %%
#Prints a summary of columns count and its dtypes but not per column information:
df_copy.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Columns: 11 entries, MovieID to Summary
# dtypes: float64(5), int64(1), object(5)
# memory usage: 53.1+ KB

# %%
df_copy.dtypes
# Out:
# MovieID           int64
# Title            object
# MPAA Rating      object
# Budget          float64
# Gross           float64
# Release Date     object
# Genre            object
# Runtime         float64
# Rating          float64
# Rating Count    float64
# Summary          object
# dtype: object

# %%
row, col = df_copy.shape
display(row)
display(col)
# Out:
# 616
# 11

# %%
df_copy.describe()
# Out:
#           MovieID        Budget         Gross     Runtime      Rating  \
# count  616.000000  6.150000e+02  6.150000e+02  615.000000  508.000000
# mean   307.500000  9.491710e+07  4.453221e+08  118.642276    6.917323
# std    177.968162  6.748114e+07  3.394075e+08   22.252376    0.888928
# min      0.000000  6.000000e+04  5.300000e+07   79.000000    4.100000
# 25%    153.750000  4.000000e+07  2.158939e+08  102.000000    6.400000
# 50%    307.500000  8.000000e+07  3.510404e+08  117.000000    6.900000
# 75%    461.250000  1.400000e+08  5.851766e+08  132.000000    7.600000
# max    615.000000  4.000000e+08  2.796000e+09  201.000000    9.000000
#
#        Rating Count
# count  5.080000e+02
# mean   3.392521e+05
# std    3.213388e+05
# min    1.491800e+04
# 25%    1.275922e+05
# 50%    2.403475e+05
# 75%    4.257000e+05
# max    2.127228e+06

# %%
# isna function will return a boolean array of either true or false if the value is null. 
# Question: the Term "Value" in this scenario, does this mean an intg value as in the number 0? or does any missing data automatically get assigned the value 0?
df_copy.isna().sum()
# boolean values: a true value is assigned a value of one. so it asks is there a null value = yes = true = 1 is added
# Out:
# MovieID           0
# Title             1
# MPAA Rating       1
# Budget            1
# Gross             1
# Release Date      1
# Genre             1
# Runtime           1
# Rating          108
# Rating Count    108
# Summary         120
# dtype: int64

# %%
#detect missing values 
df_copy.isna()
# Out:
#      MovieID  Title  MPAA Rating  Budget  Gross  Release Date  Genre  Runtime  \
# 0      False  False        False   False  False         False  False    False
# 1      False  False        False   False  False         False  False    False
# 2      False  False        False   False  False         False  False    False
# 3      False  False        False   False  False         False  False    False
# 4      False  False        False   False  False         False  False    False
# ..       ...    ...          ...     ...    ...           ...    ...      ...
# 611    False  False        False   False  False         False  False    False
# 612    False  False        False   False  False         False  False    False
# 613    False  False        False   False  False         False  False    False
# 614    False  False        False   False  False         False  False    False
# 615    False   True         True    True   True          True   True     True
#
# ...

# %%
df_copy.dropna()
#will drop all NA values
# Out:
#      MovieID                                Title MPAA Rating       Budget  \
# 0          1                   Look Who's Talking       PG-13    7500000.0
# 1          2                   Driving Miss Daisy          PG    7500000.0
# 2          3                       Turner & Hooch          PG   13000000.0
# 3          4           Born on the Fourth of July           R   14000000.0
# 4          5                      Field of Dreams          PG   15000000.0
# ..       ...                                  ...         ...          ...
# 505      506                           Big Hero 6          PG  165000000.0
# 506      507                         Interstellar       PG-13  165000000.0
# 507      508  Captain America: The Winter Soldier       PG-13  170000000.0
# 508      509       Dawn of the Planet of the Apes       PG-13  170000000.0
# 509      510              Guardians of the Galaxy       PG-13  170000000.0
#
# ...

# %%
#only drop records of a certain column
#case specific 
df_copy.dropna(subset=['Summary'])
# Out:
#      MovieID                                Title MPAA Rating       Budget  \
# 0          1                   Look Who's Talking       PG-13    7500000.0
# 1          2                   Driving Miss Daisy          PG    7500000.0
# 2          3                       Turner & Hooch          PG   13000000.0
# 3          4           Born on the Fourth of July           R   14000000.0
# 4          5                      Field of Dreams          PG   15000000.0
# ..       ...                                  ...         ...          ...
# 505      506                           Big Hero 6          PG  165000000.0
# 506      507                         Interstellar       PG-13  165000000.0
# 507      508  Captain America: The Winter Soldier       PG-13  170000000.0
# 508      509       Dawn of the Planet of the Apes       PG-13  170000000.0
# 509      510              Guardians of the Galaxy       PG-13  170000000.0
#
# ...

# %%
#check if every single value in a certain record (row) is null, then that record is dropped 
df_copy.dropna(how='all')
#replace all with 'any' to replace any with missing values 
#the .dropna funciton is only a viewing function, it is not actually changing the data frame at all. 
#add , inplace=True to save the dropped changes to the data frame or reasign to a new variable
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %%
#fill in instead of drop = fillna
#fill with value 0
df_copy.fillna(0)
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                      0           0          0.0
#
# ...

# %%
#fill with specific function depending on column
df_copy.fillna({'Summary': 1, 'MPAA Rating': 2})
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN           2          NaN
#
# ...

# %%
#use the average to fill in 
df_copy.fillna({'Runtime':df_copy['Runtime'].mean(), 'Rating':df_copy['Rating'].mean()})
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %%
#you can allso fill in with the previous fill - forward fill ffill
#or back fill, using the following value bfill
df_copy.fillna(method='bfill', limit=2)
#you can set a limit to how many values you want to allow pandas to do this for. if you have 10 missing values one after another, they might represent too grat a range to simply fill in the previous value.
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %%
#continuing exercises   
df_copy.head()
# Out:
#    MovieID                       Title MPAA Rating      Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0
#
#                                              Summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# ...

# %%
#drop the summarys column
df_copy.drop("Summary", axis="columns", inplace=True)
#this for some reason does not work if i write the .head in this same window. it does work when i move it into the next line.

# %%
df_copy.head(2)
# Out:
#    MovieID               Title MPAA Rating     Budget        Gross  \
# 0        1  Look Who's Talking       PG-13  7500000.0  296000000.0
# 1        2  Driving Miss Daisy          PG  7500000.0  145793296.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0

# %%
#column names - replace space with underscore 
#all string values should be lower case - unison 
# us rename meathod

# %%
df_copy.rename(columns = {'MovieID':'movieid', 'Title':'title', 'MPAA Rating':'mpaa_rating', 'Budget':'budget', 'Gross':'gross', 'Release Date':'release_date', 'Genre':'genre', 'Runtime':'runtime', 'Rating':'rating', 'Rating Count':'rating_count'}, inplace=True)

# %%
#just to look at column names 
df_copy.columns
# Out:
# Index(['movieid', 'title', 'mpaa_rating', 'budget', 'gross', 'release_date',
#        'genre', 'runtime', 'rating', 'rating_count'],
#       dtype='object')

# %%
#all intg values in the same unit of measurement

# %%
#drop last row where all values are NA
df_copy.drop(df_copy.index[-1], axis=0, inplace=True)
#find the function that drops all rows that are exclusively NaN values 
# NaN = not a number 
#idea: i could round the rating to make it easier to read

# %%
#use fillna() method to replace the missing values of Rating with their median
#we use mean for a normal distribution and median for a skewed distribution. 
#In this case the Rating column has a negatevly skewed distribution
df_copy["rating"].fillna(value=df_copy["rating"].median(), inplace=True)

# %%
#The Rating Count column is positively skewed
#use fillna() to replace values with the median 
df_copy["rating_count"].fillna(value=df_copy["rating_count"].median(), inplace=True)

# %%
#drop duplicates
df_copy.drop_duplicates()
# Out:
#      movieid                                  title mpaa_rating       budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 610      611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
#
# ...

# %%
#convert data types 
#Make sure numbers are stored as numerical data types
#A date should be stored as a date object, or a Unix timestamp, number of seconds ect.

# %%
#check data type
df_copy.dtypes
# Out:
# movieid           int64
# title            object
# mpaa_rating      object
# budget          float64
# gross           float64
# release_date     object
# genre            object
# runtime         float64
# rating          float64
# rating_count    float64
# dtype: object

# %%
#Convert Budget into integer type (use astype() method)
df_copy["budget"] = df_copy["budget"].astype("Int64")

# %%
#Convert Gross into integer type
df_copy["gross"] = df_copy["gross"].astype("Int64")

# %%
#change release date data type from object to string

# %%
df_copy["release_date"]
# Out:
# 0      1989-10-12
# 1      1989-12-13
# 2      1989-07-28
# 3      1989-12-20
# 4      1989-04-21
#           ...
# 610    2019-05-13
# 611    2019-06-11
# 612    2019-07-13
# 613    2019-07-09
# 614    2019-04-22
# Name: release_date, Length: 615, dtype: object

# %%
df_copy["release_date"] = pd.to_datetime(df_copy["release_date"])

# %%
#check new data type
df_copy.dtypes
# Out:
# movieid                  int64
# title                   object
# mpaa_rating             object
# budget                   Int64
# gross                    Int64
# release_date    datetime64[ns]
# genre                   object
# runtime                float64
# rating                 float64
# rating_count           float64
# dtype: object

# %% [markdown]
# Data cleaning is the process of fixing or removing incorrect, corrupted, incorrectly formatted, duplicate, or incomplete data
# Look at:
#     - Irrelevant Data (use drop)
#     - Standardize typing to all lower or upper case (use rename)
#     - Duplicates
#     - Convert Data Type ( use astype, or to_datetime)
#     - Syntax error
#     - Outliers
#     - In-record & cross-datasets errors. For ex. that the total is equal to the sum it claims to be

# %% [markdown]
# Outliers
# They are values that are significantly different from all other observations. Any data value that lies more than (1.5 * IQR) away from the Q1 and Q3 quartiles is considered an outlier.
#
# Innocent until proven guilty. Best not to remove.
#
# It is also worth mentioning that some models, like linear regression, are very sensitive to outliers. In other words, outliers might throw the model off from where most of the data lie.

# %%
#top 5 movie names 
x=df_copy.sort_values("Rating", ascending=False). head(5)
x.loc[:, ("Title", "Rating")]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[190], line 2
#       1 #top 5 movie names
# ----> 2 x=df_copy.sort_values("Rating", ascending=False). head(5)
#       3 x.loc[:, ("Title", "Rating")]
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\pandas\core\frame.py:6912, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6908 elif len(by):
#    6909     # len(by) == 1
# ...

# %%
df_copy.sort_values("Budget", ascending=False).head(5)
